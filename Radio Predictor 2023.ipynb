# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
radio_df = pd.read_excel('C:/Users/Andy-Workstation/Downloads/Predictor_Input_Cume.xlsx', engine='openpyxl', sheet_name='attributes')

# %%
radio_df
# Out:
#           Friendly Station MonthInCalendar  \
# 0    102.1  102.1 The Edge      2017-01-01
# 1    102.1  102.1 The Edge      2017-02-01
# 2    102.1  102.1 The Edge      2017-03-01
# 3    102.1  102.1 The Edge      2017-04-01
# 4    102.1  102.1 The Edge      2017-05-01
# ..                     ...             ...
# 625     FM88.1    Indie 88      2022-05-01
# 626     FM88.1    Indie 88      2022-06-01
# 627     FM88.1    Indie 88      2022-07-01
# 628     FM88.1    Indie 88      2022-08-01
# 629     FM88.1    Indie 88      2022-09-01
#
#      Announcers have a sense of humour I like  \
# 0                                        0.30
# 1                                        0.28
# 2                                        0.26
# 3                                        0.29
# 4                                        0.29
# ..                                        ...
# 625                                      0.23
# 626                                      0.25
# ...

# %%
radio_df = radio_df.drop('MonthInCalendar', axis=1)

# %%
radio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 19 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Friendly Station                                           630 non-null    object
#  1   Announcers have a sense of humour I like                   630 non-null    float64
#  2   Announcers have a wide range of knowledge                  630 non-null    float64
#  3   Fun and entertaining weekday morning show                  630 non-null    float64
#  4   Fun to listen to                                           630 non-null    float64
#  5   Gives me the information I need to get me through the day  630 non-null    float64
#  6   Has contests I want to enter                               630 non-null    float64
# ...

# %%
from pycaret.regression import *

# %%
r2 = setup(data = radio_df, target = 'Cume', session_id = 123, silent=True)
# Out:
# <style  type="text/css" >
#     #T_60e0dba2_9603_11ed_a353_001583f9d3f1row3_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_60e0dba2_9603_11ed_a353_001583f9d3f1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60e0dba2_9603_11ed_a353_001583f9d3f1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_60e0dba2_9603_11ed_a353_001583f9d3f1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_60e0dba2_9603_11ed_a353_001583f9d3f1row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_60e0dba2_9603_11ed_a353_001583f9d3f1level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
setup_df = pull()

# %%
setup_df
# Out:
# <style  type="text/css" >
#     #T_6b10693e_9603_11ed_9afd_001583f9d3f1row3_col1 {
#             background-color:  lightgreen;
#             background-color:  lightgreen;
#         }</style><table id="T_6b10693e_9603_11ed_9afd_001583f9d3f1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b10693e_9603_11ed_9afd_001583f9d3f1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6b10693e_9603_11ed_9afd_001583f9d3f1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6b10693e_9603_11ed_9afd_001583f9d3f1row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_6b10693e_9603_11ed_9afd_001583f9d3f1level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_872cb29e_9603_11ed_989d_001583f9d3f1 th {
#           text-align: left;
#     }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_872cb29e_9603_11ed_989d_001583f9d3f1row0_col5 {
# ...

# %%
compare_df = pull()

# %%
compare_df
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# et                  Extra Trees Regressor  0.0175  0.0005  0.0225  0.9291
# knn                 K Neighbors Regressor  0.0178  0.0006  0.0234  0.9233
# br                         Bayesian Ridge  0.0202  0.0007  0.0255  0.9131
# lr                      Linear Regression  0.0205  0.0007  0.0258  0.9115
# catboost               CatBoost Regressor  0.0193  0.0007  0.0252  0.9098
# huber                     Huber Regressor  0.0206  0.0007  0.0261  0.9083
# ridge                    Ridge Regression  0.0213  0.0008  0.0274  0.8991
# rf                Random Forest Regressor  0.0196  0.0008  0.0272  0.8860
# gbr           Gradient Boosting Regressor  0.0207  0.0008  0.0280  0.8853
# lightgbm  Light Gradient Boosting Machine  0.0211  0.0009  0.0287  0.8778
# ada                    AdaBoost Regressor  0.0240  0.0010  0.0313  0.8607
# xgboost         Extreme Gradient Boosting  0.0230  0.0010  0.0311  0.8520
# ...

# %%
best
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=123, verbose=0, warm_start=False)

# %%
save_model(best, 'best_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='Cume',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
# ...
